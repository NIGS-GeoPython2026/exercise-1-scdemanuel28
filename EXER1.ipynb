# %%
ice_cream_rating = 7
sleeping_rating = 10

# %%
first_name = input("What is your first name?")
last_name = input("What is your last name?")

my_name = first_name + " " + last_name
# Out:
# What is your first name? Sophia Jana
# What is your last name? De Manuel

# %%
happiness_rating= (ice_cream_rating + sleeping_rating)/2

# %% [markdown]
# print(type(ice_cream_rating))
# print(type(first_name))
# print(type(happiness_rating))

# %%
print ("My name is "  + first_name + "and I give eating ice cream a score of " + str(ice_cream_rating) + " out of 10!")
print ("I am " + my_name + " and my sleeping enjoyment rating is " + str(sleeping_rating) + "/10!")
print ("Based on the factors above, my happiness rating is " + str(happiness_rating) + " out of 10, 85.0 %")
# Out:
# My name is Sophia Jana and I give eating ice cream a score of 7 out of 10!
# I am Sophia Jana  De Manuel and my sleeping enjoyment rating is 10/10!
# Based on the factors above, my happiness rating is 8.5 out of 10, 85.0 %
